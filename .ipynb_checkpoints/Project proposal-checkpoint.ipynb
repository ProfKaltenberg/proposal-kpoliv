# %% [markdown]
# # Project proposal
# **Research Question**
#
# What factors influence hotel prices in the Dominican Republic?
#
# **Motivation**
#
# The hotel industry is a key driver of tourism in the dominican republic, understanding the factors that influence hotel prices can help reveal how customer perceptions, reflected in ratings and reviews, affect pricing strategies. Also when i saw the web page i thought it could be feasable and a good excercise to do for learning.
#
# **Data**
#
# Variables to collect by web scraping
#
# - Hotel Name (this one I’m not using it, but I would like to web scrap the names)
# - Price per Night
# - Ratings
# - Number of Reviews

# %%
# import requests
# import pandas as pd
url = "https://www.booking.com/searchresults.html?ss=Dominican+Republic"

# %% [markdown]
# **Regression Model**s:
#
# $$
# \text{Price}_i = \beta_0 + \beta_1 \cdot \text{Rating}_i + \beta_2 \cdot \text{Reviews}_i + \epsilon_i
# $$
#
# where:
#
# - $\text{Price}_i$ represents the nightly price of hotel $i$
# - $\text{Rating}_i$ represents the hotel’s review score
# - $\text{Reviews}_i$ represents the number of reviews
# - $\epsilon_i$ is the error term  views.

# %% [markdown]
# prof k:
# these websites tend to be very hard to webscrape. The question is also too narrow (and too big?  DR is a big place!)
#
# The best kidn of research question is a "Does" ir "Did" question (in economics)?  Did nyc congestion pricing decrease pricing? etc.
